# %% [markdown]
# Naive Bayes algorithms are a set of supervised statistical classification machine learning algorithms based on the **Bayes probability theorem**.
# <br>
#
# Bayes theorem states that:
# <br>
#
# P(A|B) = P(B|A) * P(A)/P(B)
# <br>
#
# An important assumption made by Bayes theorem is that **the value of a particular feature is independent from the value of any other feature for a given the class**.
# <br>
#
# I have done a sentiment analysis on the [Reddit dataset](https://www.kaggle.com/cosmos98/twitter-and-reddit-sentimental-analysis-dataset), which is a multiclass classification problem.

# %% [markdown]
# ### About the dataset used:
#
# It consists of two columns: `category` and `clean_comment`.
#
# Category column:
#
# *  1 : Indicating a Postive Sentiment
# *  0 : Indicating it is a Neutral Sentiment
# * -1 : Indicating a Negative Sentiment
#
# Comment column:
#
# These comments were made on political leaders as well as people's opinion towards the next prime minister of the Nation(in context with General Elections Held In India 2019).

# %% [markdown]
# ### Basic workflow of building the classifier:
#
# (From each comment, build a vocabulary that consists of word, it's sentiment and it's frequency.
# For any given string, it's sentiment is decided by multiplying the probability of each word occuring)
#
# * Step 1: Calculate the prior probability for each class labels
# * Step 2: Find likelihood probability with each attribute for each class
# * Step 3: Put these value in Bayes Formula and calculate posterior probability
# * Step 4: See which class has a higher probability, given the input belongs to the higher probability class.

# %% [markdown]
# # Table of contents
#
#
# 1. Loading the dataset
# <br>
#
# 2. Analysis
# <br>
#
# 3. Modelling
# <br>
#
# 4. Evaluative results
# <br>
#
# 5. Future scope

# %% [markdown]
# ## Part 1: Loading the dataset

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

import re

import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# import functions from helper.py
from helper import clean_text,find_freq,word_sentiment

# %% [markdown]
# The helper function(helper.py) consists of the following functions:
#
# 1. `clean_text` : The very first step in predict the sentiment of a given string(here, comments) is to tokenize it, i.e, represent it in a list of individual words present in the string. Also, words that don't add much meaning to the string can be removed(stop words) and the remaining words can be stemmed to generate the root words. To achieve this, in-built functions from **NLTK** have been used.
#
#
# 2. `find_freq` : We need to find frequency of each word occuring in the given dataset, this frequency is later used in the formula to compare it's occurences in different classes.
#
#
# 3. `word_sentiment` : This function gives the positive, negative and neutral words in the vocabulary that we built.

# %%
# Load stop words and function for stemming the data

stop_words = stopwords.words('english')
stemmer=PorterStemmer()

# %%
# Load the data

data=pd.read_csv("Reddit_Data.csv")

# %% [markdown]
# ## Part 2: Analysis

# %%
data.head()
# Out:
#                                        clean_comment  category
# 0   family mormon have never tried explain them t...         1
# 1  buddhism has very much lot compatible with chr...         1
# 2  seriously don say thing first all they won get...        -1
# 3  what you have learned yours and only yours wha...         0
# 4  for your own benefit you may want read living ...         1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37249 entries, 0 to 37248
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   clean_comment  37149 non-null  object
#  1   category       37249 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 582.1+ KB

# %% [markdown]
# There are 100 categories, which don't have corresponding comment, we drop those rows.

# %%
data=data.dropna()

# %%
data.head()
# Out:
#                                        clean_comment  category
# 0   family mormon have never tried explain them t...         1
# 1  buddhism has very much lot compatible with chr...         1
# 2  seriously don say thing first all they won get...        -1
# 3  what you have learned yours and only yours wha...         0
# 4  for your own benefit you may want read living ...         1

# %%
data.shape
# Out:
# (37149, 2)

# %%
data['category'].value_counts()
# Out:
#  1    15830
#  0    13042
# -1     8277
# Name: category, dtype: int64

# %% [raw]
# This can be used in case of binary classification:
#
# data = data[data.category!=0]

# %%
# positive sentiment

data.loc[data['category']==1, 'clean_comment'].iloc[0]
# Out:
# ' family mormon have never tried explain them they still stare puzzled from time time like some kind strange creature nonetheless they have come admire for the patience calmness equanimity acceptance and compassion have developed all the things buddhism teaches '

# %%
# neutral sentiment

data.loc[data['category']==0, 'clean_comment'].iloc[0]
# Out:
# 'what you have learned yours and only yours what you want teach different focus the goal not the wrapping paper buddhism can passed others without word about the buddha '

# %%
# negative sentiment

data.loc[data['category']==-1, 'clean_comment'].iloc[0]
# Out:
# 'seriously don say thing first all they won get its too complex explain normal people anyway and they are dogmatic then doesn matter what you say see mechante post and for any reason you decide later life move from buddhism and that doesn suit you identity though you still get keep all the wisdom then your family will treat you like you went through weird hippy phase for while there didncha and you never hear the end pro tip don put one these your wall jpg '

# %% [markdown]
# An observation that can be made about the text is that it doesn't contain **capital letters** and punctuations or **user handles**.

# %% [markdown]
# Unlike most of the models, naive bayes doesn't require encoding of y(here,category) variable, since it deals with discrete distribution.

# %% [markdown]
# ## Part 3: Modelling

# %%
# splitting the data into train and validation set

X_train,X_val,y_train,y_val=train_test_split(data['clean_comment'],data['category'],test_size=0.2,
                                             stratify=data['category'],shuffle=True)

# %%
X_train.head()
# Out:
# 5197                 could you tell bit about the crawler
# 36685     city president the muslim rashtriya manch riy...
# 31018    bjp invest the max marketing than any other co...
# 24588    prediction 2019 aap wins least more state elec...
# 26571     know which neighbors went all maga ten years ...
# Name: clean_comment, dtype: object

# %% [markdown]
# The training data consists strings.
# <br>
# Given a string, the vocabulary returns a pair of tuple (word,string):frequency.
# For example, consider a list of strings
# <br>`["it's  beautiful day", "life is beautiful"]`.
#
# <br>The vocabulary would return
# the following key valie pairs:
# `{("beautiful",1):2 ("life",1):1 ("day",1):1}`

# %%
def vocabulary(voc,comments,ys):
    '''
    Input:
        voc: existing vocabulary 
        comments: the dataset containing comments
        ys: the label corresponding to each comment
    Output:
        voc: updated vocabulary(a dictionary containing (word,label) as the key 
                                and it's corresponding frequency as value)
        
        It is of the format : {(word,label):frequency}
    '''
    for y,comm in zip(ys,comments):
        # clean and tokenize each comm by passing through the helper function
        for word in clean_text(comm, stop_words, stemmer):
            pair=(word,y)
            
            # if pair already exists in vocabulary, increase frequency by 1
            if pair in voc:
                voc[pair]+=1
                
            #if the word is occuring for the first time, set the frequency to 1
            else:
                voc[pair]=1
    return voc

# %%
# get the vocabulary by passing training dataset

vocab=vocabulary({}, X_train, y_train)

# %%
vocab
# Out:
# {('could', 0): 85,
#  ('tell', 0): 61,
#  ('bit', 0): 19,
#  ('crawler', 0): 1,
#  ('citi', -1): 65,
#  ('presid', -1): 98,
#  ('muslim', -1): 414,
#  ('rashtriya', -1): 3,
#  ('manch', -1): 6,
#  ('riyaz', -1): 1,
#  ('khan', -1): 42,
#  ('alleg', -1): 38,
#  ('rss', -1): 112,
#  ('bjp', -1): 1198,
#  ('ignor', -1): 84,
#  ('demand', -1): 43,
#  ('claim', -1): 157,
#  ('000', -1): 39,
#  ('member', -1): 89,
#  ('join', -1): 40,
#  ('congress', -1): 546,
#  ('along', -1): 41,
#  ('functionari', -1): 1,
#  ('invest', -1): 33,
#  ('max', -1): 7,
#  ('market', -1): 46,
#  ('compani', -1): 78,
#  ('come', -1): 420,
#  ('predict', 1): 95,
#  ('2019', 1): 192,
#  ('aap', 1): 444,
#  ('win', 1): 688,
#  ('least', 1): 251,
#  ('state', 1): 949,
#  ('elect', 1): 960,
#  ('seat', 1): 251,
#  ('know', 0): 195,
#  ('neighbor', 0): 5,
#  ('went', 0): 28,
#  ('maga', 0): 10,
#  ('ten', 0): 24,
#  ('year', 0): 154,
#  ('amnesia', 0): 2,
#  ('kick', 0): 9,
#  ('gonna', 0): 52,
#  ('make', 0): 207,
#  ('big', 0): 64,
#  ('poster', 0): 11,
#  ('shame', 0): 22,
#  ('vote', 0): 229,
#  ('trump', 0): 88,
#  ('4x12', 0): 1,
#  ('foot', 0): 9,
#  ('yard', 0): 7,
#  ('sign', 0): 22,
#  ('actual', 0): 85,
#  ('size', 0): 8,
#  ('rural', 0): 4,
#  ('cute', 1): 33,
#  ('hilari', 1): 45,
#  ('classic', 1): 28,
#  ('tvf', 1): 5,
#  ('total', 1): 158,
#  ('make', 1): 1482,
#  ('sens', 1): 197,
#  ('would', 1): 1751,
#  ('also', 1): 1190,
#  ('add', 1): 121,
#  ('upgrad', 1): 43,
#  ('music', 1): 50,
#  ('file', 1): 68,
#  ('qualiti', 1): 117,
#  ('argument', 1): 104,
#  ('sure', 1): 536,
#  ('stream', 1): 41,
#  ('320', 1): 1,
#  ('kbp', 1): 2,
#  ('flac', 1): 3,
#  ('bahujanahitāya', 1): 1,
#  ('bahujanasukhāya', 1): 1,
#  ('lokānukampāya', 1): 1,
#  ('good', 1): 2423,
#  ('mani', 1): 996,
#  ('happi', 1): 227,
#  ('compass', 1): 17,
#  ('world', 1): 548,
#  ('gautama', 1): 1,
#  ('buddha', 1): 102,
#  ('silenc', 0): 4,
#  ('sort', 0): 17,
#  ('samdhi', 0): 1,
#  ('populac', 0): 2,
#  ('lot', 0): 385,
#  ('tech', 0): 3,
#  ('savvi', 0): 1,
#  ('peopl', 0): 325,
#  ('bear', 0): 8,
#  ('system', 0): 20,
#  ('play', 0): 60,
#  ('teddi', 0): 1,
#  ('great', 1): 661,
#  ('updat', 1): 85,
#  ('alway', 1): 392,
#  ('thank', 1): 632,
#  ('sister', 1): 37,
#  ('pede', 1): 16,
#  ('well', 1): 948,
#  ('given', 1): 239,
#  ('transit', 1): 24,
#  ('kejriw', 1): 142,
#  ('illog', 1): 1,
#  ('indian', 1): 1303,
#  ('apt', 1): 11,
#  ('name', 1): 364,
#  ('page', 1): 109,
#  ('realli', 1): 970,
#  ('need', 1): 1052,
#  ('explan', 1): 36,
#  ('year', 1): 1097,
#  ('ago', 1): 140,
#  ('godhra', 1): 13,
#  ('carnag', 1): 4,
#  ('vir', 1): 2,
#  ('sanghvi', 1): 4,
#  ('former', 1): 51,
#  ('editor', 1): 19,
#  ('hindustan', 1): 12,
#  ('time', 1): 1419,
#  ('made', 1): 504,
#  ('lifetim', 1): 17,
#  ('confess', 1): 7,
#  ('media', 1): 734,
#  ('report', 1): 317,
#  ('commun', 1): 396,
#  ('violenc', 1): 116,
#  ('detail', 1): 111,
#  ('aspx', 1): 15,
#  ('key', 1): 62,
#  ('611', 1): 1,
#  ('answer', 1): 188,
#  ('suspect', 1): 38,
#  ('program', 1): 62,
#  ('see', 1): 1106,
#  ('hindu', 1): 685,
#  ('muslim', 1): 763,
#  ('relat', 1): 188,
#  ('simplist', 1): 6,
#  ('term', 1): 259,
#  ('provok', 1): 6,
#  ('suffer', 1): 97,
#  ('formula', 1): 7,
#  ('work', 1): 1009,
#  ('clear', 1): 182,
#  ('arm', 1): 66,
#  ('mob', 1): 50,
#  ('murder', 1): 82,
#  ('unarm', 1): 2,
#  ('simpli', 1): 109,
#  ('know', 1): 1183,
#  ('cope', 1): 6,
#  ('shi', 1): 7,
#  ('away', 1): 219,
#  ('truth', 1): 110,
#  ('commit', 1): 61,
#  ('act', 1): 223,
#  ('indefens', 1): 2,
#  ('resort', 1): 32,
#  ('blame', 1): 138,
#  ('victim', 1): 73,
#  ('cours', 1): 129,
#  ('ration', 1): 37,
#  ('reason', 1): 409,
#  ('offer', 1): 111,
#  ('stand', 1): 196,
#  ('minor', 1): 217,
#  ('therefor', 1): 37,
#  ('deserv', 1): 83,
#  ('special', 1): 112,
#  ('consider', 1): 25,
#  ('alreadi', 1): 301,
#  ('face', 1): 267,
#  ('discrimin', 1): 35,
#  ('harder', 1): 30,
#  ('inflam', 1): 1,
#  ('sentiment', 1): 33,
#  ('irrespons', 1): 6,
#  ('someth', 1): 551,
#  ('journalist', 1): 99,
#  ('believ', 1): 442,
#  ('ever', 1): 305,
#  ('admit', 1): 63,
#  ('public', 1): 353,
#  ('forum', 1): 28,
#  ('moral', 1): 87,
#  ('justifi', 1): 53,
#  ('view', 1): 234,
#  ('outsid', 1): 123,
#  ('ideolog', 1): 94,
#  ('circl', 1): 46,
#  ('wide', 1): 43,
#  ('attack', 1): 374,
#  ('profess', 1): 11,
#  ('wrote', 1): 40,
#  ('articl', 1): 292,
#  ('figur', 1): 101,
#  ('talk', 1): 477,
#  ('interfaith', 1): 2,
#  ('issu', 1): 538,
#  ('follow', 1): 327,
#  ('compromis', 1): 29,
#  ('secular', 1): 141,
#  ('idealog', 1): 2,
#  ('mainli', 1): 25,
#  ('polit', 1): 910,
#  ('construct', 1): 89,
#  ('true', 1): 352,
#  ('henc', 1): 58,
#  ('implicit', 1): 3,
#  ('agreement', 1): 46,
#  ('come', 1): 898,
#  ('lesser', 1): 37,
#  ('evil', 1): 51,
#  ('like', 1): 2680,
#  ('fundamentalist', 1): 16,
#  ('non', 1): 274,
#  ('bjp', 1): 2325,
#  ('parti', 1): 1186,
#  ('pander', 1): 18,
#  ('duti', 1): 34,
#  ('remain', 1): 112,
#  ('silent', 1): 43,
#  ('even', 1): 1497,
#  ('support', 1): 801,
#  ('peopl', 1): 2892,
#  ('sake', 1): 30,
#  ('import', 1): 355,
#  ('goal', 1): 82,
#  ('fight', 1): 242,
#  ('sangh', 1): 21,
#  ('parivar', 1): 6,
#  ('majoritarian', 1): 9,
#  ('condon', 1): 7,
#  ('mudi', 0): 24,
#  ('resign', 0): 12,
#  ('kejriw', 0): 56,
#  ('koi', 0): 40,
#  ('buddhi', 0): 2,
#  ('danga', 0): 1,
#  ('karwayega', 0): 1,
#  ('ye', 1): 268,
#  ('point', 1): 545,
#  ('annoy', 1): 19,
#  ('joy', 1): 23,
#  ('offic', 1): 224,
#  ('night', 1): 82,
#  ('gst', 0): 14,
#  ('tax', 0): 45,
#  ('get', 0): 332,
#  ('reduc', 0): 12,
#  ('inadequ', 0): 1,
#  ('rainfal', 0): 1,
#  ('monsoon', 0): 1,
#  ('india', 0): 491,
#  ('may', 0): 67,
#  ('reconsid', 0): 1,
#  ('obor', 0): 2,
#  ('much', 1): 1091,
#  ('hand', 1): 263,
#  ('job', 1): 406,
#  ('btw', 1): 35,
#  ('fuck', -1): 1054,
#  ('countri', -1): 562,
#  ('rape', -1): 104,
#  ('happen', -1): 329,
#  ('piec', -1): 51,
#  ('shit', -1): 519,
#  ('anyth', -1): 210,
#  ('forget', -1): 54,
#  ('modi', -1): 1077,
#  ('guy', -1): 346,
#  ('right', -1): 305,
#  ('critic', -1): 139,
#  ('anyon', -1): 169,
#  ('els', -1): 102,
#  ('evid', 1): 113,
#  ('age', 1): 101,
#  ('unquest', 1): 1,
#  ('kowtow', 1): 1,
#  ('foreign', 1): 131,
#  ('tongu', 1): 19,
#  ('end', 1): 379,
#  ('vive', 1): 2,
#  ('differ', 1): 475,
#  ('french', 1): 21,
#  ('might', 1): 362,
#  ('say', 1): 1158,
#  ('lol', 1): 388,
#  ('tree', 0): 9,
#  ('terrorist', 0): 36,
#  ('iaf', 0): 20,
#  ('mesa', -1): 3,
#  ('novaprim', -1): 1,
#  ('sad', -1): 146,
#  ('day', -1): 347,
#  ('mayb', 1): 256,
#  ('small', 1): 151,
#  ('incid', 1): 124,
#  ('statist', 1): 33,
#  ('die', 1): 187,
#  ('popul', 1): 212,
#  ('billion', 1): 92,
#  ('worth', 1): 125,
#  ('cough', 1): 5,
#  ('modi', 0): 701,
#  ('act', 0): 26,
#  ('upon', 0): 9,
#  ('may', 1): 459,
#  ('new', 1): 773,
#  ('power', 1): 701,
#  ('congress', 1): 1083,
#  ('yeah', 1): 102,
#  ('let', 1): 579,
#  ('cri', 1): 70,
#  ('continu', 1): 197,
#  ('corrupt', 1): 342,
#  ('stuff', 1): 227,
#  ('choic', 1): 102,
#  ('sooner', 1): 16,
#  ('later', 1): 121,
#  ('back', 1): 593,
#  ('scare', 1): 66,
#  ('loos', 1): 43,
#  ('feel', 1): 575,
#  ('defens', 1): 61,
#  ('modi', 1): 2283,
#  ('polici', 1): 284,
#  ('deep', 1): 56,
#  ('lose', 1): 219,
#  ('everi', 1): 577,
#  ('critic', 1): 260,
#  ('gnaw', 1): 1,
#  ('insecur', 1): 18,
#  ('bite', 1): 19,
#  ('nail', 1): 15,
#  ('look', 1): 887,
#  ('flop', 1): 8,
#  ('becom', 1): 505,
#  ('paranoid', 1): 5,
#  ('two', 1): 383,
#  ('pais', 1): 8,
#  ('pkmkb', 0): 2,
#  ('never', 0): 112,
#  ('pakistan', 0): 127,
#  ('pappu', 0): 28,
#  ('find', 1): 351,
#  ('funni', 1): 114,
#  ('women', 1): 173,
#  ('hitwomen', 1): 2,
#  ('bomb', 1): 82,
#  ('bengal', 1): 54,
#  ('vanguard', 1): 9,
#  ('jihadi', 1): 16,
#  ('complet', 1): 279,
#  ('ignor', 1): 158,
#  ('moment', 1): 111,
#  ('thread', 1): 242,
#  ('front', 1): 118,
#  ('vote', 1): 956,
#  ('top', 1): 351,
#  ('madraasa', 1): 1,
#  ('terror', 1): 151,
#  ('none', 1): 92,
#  ('hindutva', 1): 103,
#  ('rss', 1): 222,
#  ('bash', 1): 19,
#  ('pictur', 1): 137,
#  ('frequent', 1): 28,
#  ('flyer', 1): 3,
#  ('aap', -1): 192,
#  ('slowli', -1): 20,
#  ('turn', -1): 134,
#  ('pass', -1): 53,
#  ('real', -1): 107,
#  ('issu', -1): 228,
#  ('repeat', -1): 13,
#  ('alreadi', -1): 114,
#  ('tri', -1): 315,
#  ('one', -1): 848,
#  ('agenda', -1): 55,
#  ('elect', -1): 342,
#  ('stop', -1): 197,
#  ('sul', 0): 7,
#  ('molis', 0): 2,
#  ('sono', 0): 55,
#  ('morto', 0): 2,
#  ('yogi', 0): 22,
#  ('mentor', 0): 1,
#  ('rustl', 0): 1,
#  ('jimmi', 0): 12,
#  ('mean', 1): 443,
#  ('get', 1): 1984,
#  ('cover', 1): 98,
#  ('case', 1): 380,
#  ('whole', 1): 276,
#  ('armi', 1): 187,
#  ('redditor', 1): 19,
#  ('post', 1): 913,
#  ('multipl', 1): 84,
#  ('variou', 1): 80,
#  ('sourc', 1): 281,
#  ('exactli', 1): 151,
#  ('reddit', 1): 185,
#  ('homepag', 1): 6,
#  ('want', 1): 1142,
#  ('massag', 1): 4,
#  ('ego', 1): 22,
#  ('call', 1): 517,
#  ('terrorist', 1): 243,
#  ('aapki', 0): 2,
#  ('gaand', 0): 19,
#  ('mein', 0): 85,
#  ('yeh', 0): 38,
#  ('phasa', 0): 1,
#  ('hua', 0): 17,
#  ('tha', 0): 34,
#  ('pleas', 0): 149,
#  ('someon', 0): 119,
#  ('bring', 0): 32,
#  ('beggar', 0): 3,
#  ('formal', 0): 2,
#  ('economi', 0): 11,
#  ('enabl', 0): 4,
#  ('loan', 0): 18,
#  ('beg', 0): 6,
#  ('busi', 0): 21,
#  ('pli', 0): 4,
#  ('educ', 0): 34,
#  ('futur', 0): 29,
#  ('aspir', 0): 1,
#  ('excel', 1): 87,
#  ('clinton', 0): 12,
#  ('pedophil', 0): 2,
#  ('ring', 0): 6,
#  ('truth', 0): 20,
#  ('stranger', 0): 4,
#  ('fiction', 0): 3,
#  ('thing', 1): 1238,
#  ('must', 1): 269,
#  ('defend', 1): 66,
#  ('saffron', 1): 28,
#  ('dot', 1): 8,
#  ('blood', 1): 47,
#  ('sweat', 1): 2,
#  ('script', 1): 48,
#  ('kar', 1): 31,
#  ('sevak', 1): 5,
#  ('rememb', 1): 202,
#  ('day', 1): 709,
#  ('glori', 1): 8,
#  ('betray', 1): 22,
#  ('brother', 1): 74,
#  ('march', 1): 54,
#  ('2018', 1): 79,
#  ('pleas', 1): 380,
#  ('alt', 1): 13,
#  ('account', 1): 224,
#  ('guy', 1): 626,
#  ('around', 1): 322,
#  ('dharmo', 1): 1,
#  ('rakshati', 1): 1,
#  ('rakshitaha', 1): 1,
#  ('jai', 1): 45,
#  ('sri', 1): 29,
#  ('ram', 1): 133,
#  ('kehna', 0): 3,
#  ('kya', 0): 193,
#  ('chaht', 0): 4,
#  ('bhai', 0): 76,
#  ('consid', 1): 263,
#  ('cool', 1): 124,
#  ('bad', 1): 219,
#  ('tast', 1): 29,
#  ('wonder', 1): 204,
#  ('think', 1): 1450,
#  ('happen', 1): 617,
#  ('next', 1): 353,
#  ('khalistani', 1): 5,
#  ('wake', 1): 20,
#  ('hope', 1): 515,
#  ('wash', 1): 22,
#  ('flow', 1): 24,
#  ('river', 1): 37,
#  ('one', 1): 2025,
#  ('separ', 1): 68,
#  ('probabl', 1): 288,
#  ('caus', 1): 203,
#  ('snowbal', 1): 1,
#  ('effect', 1): 159,
#  ('rest', 1): 136,
#  ('request', 1): 49,
#  ('geronimo', 1): 1,
#  ('jpg', 1): 84,
#  ('famou', 1): 48,
#  ('nativ', 1): 41,
#  ('american', 1): 164,
#  ('think', 0): 244,
#  ('twitter', 0): 85,
#  ('islam', 1): 149,
#  ('fundament', 1): 40,
#  ('opposit', 1): 255,
#  ('read', 1): 458,
#  ('lot', 1): 737,
#  ('twitter', 1): 151,
#  ('percol', 1): 2,
#  ('gener', 1): 405,
#  ('prefac', 1): 2,
#  ('liber', 1): 158,
#  ('heavi', 1): 27,
#  ('dose', 1): 8,
#  ('enlightenedcentr', 1): 1,
#  ('strong', 1): 213,
#  ('team', 1): 859,
#  ('behest', 1): 2,
#  ('hint', 1): 20,
#  ('go', 1): 703,
#  ('countri', 1): 1199,
#  ('yogi', 1): 60,
#  ('somewher', 1): 39,
#  ('somebodi', 1): 34,
#  ('lynch', 1): 49,
#  ('take', 1): 921,
#  ('milch', 1): 1,
#  ('cow', 1): 154,
#  ('home', 1): 187,
#  ('heard', 1): 154,
#  ('jharkhand', 1): 14,
#  ('tv', 1): 4,
#  ('jsp', 1): 1,
#  ('nope', 1): 20,
#  ('right', 1): 1321,
#  ('leader', 1): 499,
#  ('choos', 1): 94,
#  ('bidder', 1): 5,
#  ('auction', 1): 38,
#  ('popular', 1): 135,
#  ('talent', 1): 29,
#  ('servic', 1): 140,
#  ('flatter', 1): 2,
#  ('instead', 1): 232,
#  ('legisl', 1): 34,
#  ('instrument', 1): 20,
#  ('guid', 1): 67,
#  ('edmund', 1): 1,
#  ('burk', 1): 1,
#  ('expand', 1): 30,
#  ('adjoin', 1): 5,
#  ('area', 1): 208,
#  ('delhi', 1): 328,
#  ('east', 1): 62,
#  ('rajasthan', 1): 78,
#  ('specif', 1): 91,
#  ('western', 1): 109,
#  ('lack', 1): 127,
#  ('govern', 1): 1159,
#  ('region', 1): 117,
#  ('develop', 1): 395,
#  ('orient', 1): 21,
#  ('glad', 1): 82,
#  ('bsnl', 1): 4,
#  ('farm', -1): 10,
#  ('loan', -1): 56,
#  ('waver', -1): 1,
#  ('announc', -1): 34,
#  ('yesterday', -1): 43,
#  ('yeddeyurappa', -1): 1,
#  ('would', -1): 645,
#  ('farmer', -1): 25,
#  ('still', -1): 303,
#  ('get', -1): 827,
#  ('reffffffffffff', -1): 1,
#  ('game', -1): 212,
#  ('plan', -1): 92,
#  ('yeddyurappa', -1): 7,
#  ('waiver', -1): 12,
#  ('googli', -1): 1,
#  ('may', -1): 166,
#  ('hit', -1): 67,
#  ('wicket', -1): 3,
#  ('bank', -1): 117,
#  ('better', -1): 125,
#  ('prep', -1): 2,
#  ('bloodi', -1): 26,
#  ('blow', -1): 19,
#  ('4472993', -1): 1,
#  ('html', -1): 76,
#  ('wait', 0): 93,
#  ('raid', 0): 7,
#  ('shoe', 0): 5,
#  ('ban', 0): 96,
#  ('xiaomi', 0): 1,
#  ('paytm', 0): 1,
#  ('chines', 0): 11,
#  ('compani', 0): 15,
#  ('support', 0): 94,
#  ('hafeez', 0): 1,
#  ('saeed', 0): 3,
#  ('relex', 0): 1,
#  ('men', 0): 11,
#  ('go', 0): 151,
#  ('dnt', 0): 3,
#  ('cmpre', 0): 1,
#  ('ram', 0): 50,
#  ('prahlad', 0): 1,
#  ('krishna', 0): 4,
#  ('bjp', 0): 559,
#  ('cell', 0): 20,
#  ('post', 0): 231,
#  ('low', 0): 30,
#  ('effort', 0): 5,
#  ('maymay', 0): 3,
#  ('pappu', -1): 28,
#  ('seed', -1): 5,
#  ('saala', -1): 6,
#  ('sorri', -1): 159,
#  ('pic', 0): 15,
#  ('meme', 0): 36,
#  ('replac', 0): 15,
#  ('symbol', 0): 8,
#  ('etc', 0): 33,
#  ('search', -1): 24,
#  ('hand', -1): 154,
#  ('manish', -1): 4,
#  ('rich', -1): 32,
#  ('man', -1): 198,
#  ('situat', -1): 71,
#  ('preval', -1): 7,
#  ('rahul', -1): 86,
#  ('sinha', -1): 11,
#  ('parti', -1): 526,
#  ('continu', -1): 92,
#  ('even', -1): 677,
#  ('dilip', -1): 1,
#  ('ghosh', -1): 1,
#  ('reign', -1): 5,
#  ('wish', -1): 56,
#  ('ancestr', -1): 2,
#  ('properti', -1): 11,
#  ('could', -1): 207,
#  ('pay', -1): 83,
#  ('lot', -1): 270,
#  ('money', -1): 247,
#  ('ticket', -1): 20,
#  ('said', -1): 355,
#  ('ansari', -1): 5,
#  ('later', -1): 57,
#  ('defect', -1): 5,
#  ('tmc', -1): 7,
#  ('candid', -1): 87,
#  ('figur', -1): 42,
#  ('first', -1): 159,
#  ('list', -1): 65,
#  ('wonder', -1): 68,
#  ('lost', -1): 98,
#  ('amit', -1): 28,
#  ('shah', -1): 34,
#  ('seem', -1): 191,
#  ('like', -1): 1129,
#  ('seriou', -1): 93,
#  ('west', -1): 22,
#  ('bengal', -1): 20,
#  ('ago', 0): 19,
#  ('manmohan', 0): 24,
#  ('singh', 0): 44,
#  ('say', 0): 262,
#  ('someth', 0): 137,
#  ('namo', 0): 99,
#  ('enough', 0): 40,
#  ('alreadi', 0): 58,
#  ('kkr', 1): 15,
#  ('dinesh', 1): 2,
#  ('karthik', 1): 5,
#  ('upcom', 1): 26,
#  ('player', 1): 67,
#  ('vote', -1): 443,
#  ('altern', -1): 27,
#  ('case', -1): 213,
#  ('hindutva', -1): 58,
#  ('well', -1): 273,
#  ('understood', -1): 6,
#  ('howev', -1): 60,
#  ('fake', -1): 151,
#  ('news', -1): 379,
#  ('gener', -1): 114,
#  ('factori', -1): 9,
#  ('utter', -1): 14,
#  ('disregard', -1): 7,
#  ('institut', -1): 40,
#  ('check', -1): 66,
#  ('worri', -1): 40,
#  ('recent', -1): 69,
#  ('budget', -1): 22,
#  ('process', -1): 40,
#  ('total', -1): 66,
#  ('mockeri', -1): 1,
#  ('parliamentari', -1): 7,
#  ('proceed', -1): 6,
#  ('speaker', -1): 22,
#  ('constantli', -1): 16,
#  ('adjourn', -1): 1,
#  ('hous', -1): 102,
#  ('minut', -1): 28,
#  ('avoid', -1): 26,
#  ('confid', -1): 15,
#  ('motion', -1): 3,
#  ('vice', -1): 11,
#  ('declin', -1): 6,
#  ('accept', -1): 76,
#  ('impeach', -1): 3,
#  ('understand', -1): 141,
#  ('chairman', -1): 13,
#  ('alway', -1): 189,
#  ('bias', -1): 20,
#  ('amount', -1): 56,
#  ('contempt', -1): 3,
#  ('shown', -1): 22,
#  ('never', -1): 244,
#  ('heard', -1): 53,
#  ('judiciari', -1): 16,
#  ('anoth', -1): 183,
#  ('victim', -1): 70,
#  ('complet', -1): 110,
#  ('subjug', -1): 4,
#  ('keep', -1): 177,
#  ('govt', -1): 181,
#  ('obviou', -1): 31,
#  ('dirt', -1): 6,
#  ('cji', -1): 2,
#  ('use', -1): 402,
#  ('gain', -1): 38,
#  ('benefit', -1): 40,
#  ('poor', -1): 152,
#  ('much', -1): 294,
#  ('bad', -1): 438,
#  ('public', -1): 157,
#  ('support', -1): 328,
#  ('yet', -1): 96,
#  ('basic', -1): 65,
#  ('idea', -1): 112,
#  ('build', -1): 66,
#  ('authoritarian', -1): 8,
#  ('empir', -1): 6,
#  ('good', -1): 227,
#  ('democraci', -1): 82,
#  ('might', -1): 146,
#  ('failur', -1): 50,
#  ('develop', -1): 134,
#  ('hope', -1): 193,
#  ('grow', -1): 29,
#  ('incorpor', -1): 2,
#  ('everi', -1): 270,
#  ('voic', -1): 47,
#  ('see', -1): 420,
#  ('futur', -1): 46,
#  ('danger', -1): 64,
#  ('indian', 0): 201,
#  ('respons', 0): 15,
#  ('pass', 0): 34,
#  ('test', 0): 12,
#  ('base', 0): 39,
#  ('intellig', 0): 3,
#  ('jaish', 0): 8,
#  ('attack', 0): 56,
#  ('short', -1): 25,
#  ('major', -1): 169,
#  ('probabl', -1): 81,
#  ('take', -1): 393,
#  ('mn', -1): 8,
#  ('independ', -1): 40,
#  ('lift', 0): 5,
#  ('polici', -1): 114,
#  ('impact', -1): 10,
#  ('lower', -1): 29,
#  ('middl', -1): 51,
#  ('class', -1): 73,
#  ('peopl', -1): 1260,
#  ('scheme', -1): 55,
#  ('lpg', -1): 3,
#  ('connect', -1): 47,
#  ('soil', -1): 10,
#  ('health', -1): 29,
#  ('card', -1): 37,
#  ('account', -1): 118,
#  ('insur', -1): 13,
#  ('etc', -1): 186,
#  ('ad', -1): 55,
#  ('tremend', -1): 3,
#  ('valu', -1): 46,
#  ('start', -1): 287,
#  ('wit', -1): 19,
#  ('consider', -1): 8,
#  ('fail', -1): 125,
#  ('bring', -1): 92,
#  ('back', -1): 261,
#  ('power', -1): 267,
#  ('year', -1): 438,
#  ('receiv', -1): 28,
#  ('6000', -1): 4,
#  ('per', -1): 130,
#  ('month', -1): 111,
#  ('douch', -1): 1,
#  ('promis', -1): 53,
#  ('cut', -1): 46,
#  ('tie', -1): 25,
#  ('india', -1): 1057,
#  ('emigr', -1): 2,
#  ('abroad', -1): 14,
#  ('best', 1): 962,
#  ('overal', 1): 403,
#  ('submitt', 1): 186,
#  ('old', -1): 114,
#  ('rehash', -1): 3,
#  ('sever', -1): 50,
#  ('time', -1): 591,
#  ('want', -1): 379,
#  ('give', -1): 287,
#  ('asylum', -1): 4,
#  ('bangladeshi', -1): 7,
#  ('hindu', -1): 315,
#  ('refuge', -1): 17,
#  ('came', -1): 79,
#  ('escap', -1): 9,
#  ('persecut', -1): 14,
#  ('islam', -1): 82,
#  ('radic', -1): 17,
#  ('home', -1): 72,
#  ('increasingli', -1): 14,
#  ('common', -1): 129,
#  ('problem', -1): 179,
#  ('bangladesh', -1): 21,
#  ('illeg', -1): 61,
#  ('migrant', -1): 9,
#  ('econom', -1): 59,
#  ('opportun', -1): 19,
#  ('number', -1): 117,
#  ('simpli', -1): 45,
#  ('massiv', -1): 35,
#  ('caus', -1): 85,
#  ('demograph', -1): 4,
#  ('chang', -1): 233,
#  ('indian', -1): 574,
#  ('state', -1): 394,
#  ('bhakti', 0): 4,
#  ('shakti', 0): 5,
#  ('hai', 0): 447,
#  ('kungen', 0): 1,
#  ('client', 0): 2,
#  ('safari', 0): 1,
#  ('prmd', 0): 1,
#  ('inv', 0): 1,
#  ('sourc', 0): 111,
#  ('lnm', 0): 1,
#  ('tbm', 0): 1,
#  ('isch', 0): 1,
#  ('ved', 0): 1,
#  ('0ahukewjxzbvkk5rsahvgvhokhwt', 0): 1,
#  ('aeeq', 0): 1,
#  ('auibygb', 0): 1,
#  ('biw', 0): 1,
#  ('375', 0): 1,
#  ('bih', 0): 1,
#  ('559', 0): 1,
#  ('upqxkvvrgcwnkm', 0): 1,
#  ('add', 0): 55,
#  ('king', 0): 13,
#  ('sweden', 0): 2,
#  ('would', 0): 186,
#  ('happiest', 0): 1,
#  ('swede', 0): 1,
#  ('ever', 0): 49,
#  ('human', 1): 152,
#  ('casualti', 1): 25,
#  ('iaf', 1): 72,
#  ('airstrik', 1): 22,
#  ('pakistan', 1): 605,
#  ('lawmak', 1): 12,
#  ('ahluwalia', 1): 1,
#  ('india', 1): 2707,
#  ('news', 1): 505,
#  ('ad', 1): 148,
#  ('neither', 1): 59,
#  ('prime', 1): 251,
#  ('minist', 1): 473,
#  ('narendra', 1): 140,
#  ('spokesperson', 1): 24,
#  ('claim', 1): 277,
#  ('300', 1): 41,
#  ('kill', 1): 285,
#  ('nation', 1): 776,
#  ('intern', 1): 140,
#  ('first', 1): 752,
#  ('speech', 1): 246,
#  ('churu', 1): 2,
#  ('said', 1): 700,
#  ('amit', 1): 74,
#  ('shah', 1): 137,
#  ('anywher', 1): 48,
#  ('ask', 1): 534,
#  ('thought', 1): 312,
#  ('hillari', 1): 33,
#  ('narcissist', 1): 12,
#  ('dump', 1): 25,
#  ('guilt', 1): 5,
#  ('other', 1): 245,
#  ('upon', 1): 74,
#  ('achiev', 1): 139,
#  ('implod', 1): 3,
#  ('project', 1): 222,
#  ('accus', 1): 86,
#  ('trump', 1): 345,
#  ('tax', 1): 221,
#  ('evas', 1): 6,
#  ('check', 1): 180,
#  ('today', 1): 305,
#  ('charg', 1): 85,
#  ('tie', 1): 45,
#  ('russia', 1): 44,
#  ('bulli', 1): 21,
#  ('toward', 1): 210,
#  ('someon', 1): 425,
#  ('tri', 1): 719,
#  ('child', 1): 50,
#  ('rape', 1): 179,
#  ('epstein', 1): 6,
#  ('unfit', 1): 5,
#  ('tempera', 1): 3,
#  ('help', 1): 445,
#  ('telegraph', 1): 13,
#  ('behavior', 1): 31,
#  ('way', 1): 948,
#  ('addit', 1): 45,
#  ('stupid', 1): 74,
#  ('brilliant', 1): 73,
#  ('parad', 1): 8,
#  ('unwittingli', 1): 2,
#  ('scene', 1): 38,
#  ('crime', 1): 76,
#  ('inwardli', 1): 1,
#  ('laugh', 1): 99,
#  ('clueless', 1): 13,
#  ('prove', 1): 121,
#  ('unworthi', 1): 1,
#  ('insect', 1): 1,
#  ('entir', 1): 236,
#  ('bug', 1): 9,
#  ('step', 1): 166,
#  ('shove', 1): 13,
#  ('trip', 1): 28,
#  ('120', 1): 24,
#  ('never', 1): 513,
#  ('tell', 1): 257,
#  ('noth', 1): 356,
#  ('obvious', 1): 79,
#  ('foia', 1): 1,
#  ('secret', 1): 32,
#  ('log', 1): 21,
#  ('travel', 1): 91,
#  ('schedul', 1): 13,
#  ('oversea', 1): 12,
#  ('overlook', 1): 9,
#  ('bring', 1): 197,
#  ('worker', 1): 81,
#  ('build', 1): 215,
#  ('pay', 1): 203,
#  ('client', 1): 11,
#  ('supposedli', 1): 20,
#  ('swarm', 1): 1,
#  ('underag', 1): 5,
#  ('children', 1): 68,
#  ('border', 1): 100,
#  ('mind', 1): 259,
#  ('woman', 1): 97,
#  ('told', 1): 148,
#  ('long', 1): 430,
#  ('villag', 1): 112,
#  ('rais', 1): 99,
#  ('kid', 1): 130,
#  ('protégé', 1): 1,
#  ('huma', 1): 2,
#  ('seem', 1): 473,
#  ('cut', 1): 108,
#  ('cloth', 1): 26,
#  ('photo', 1): 109,
#  ('grandkid', 1): 3,
#  ('born', 1): 61,
#  ('big', 1): 317,
#  ('part', 1): 355,
#  ('miss', 1): 132,
#  ('love', 1): 634,
#  ('short', 1): 100,
#  ('watch', 1): 258,
#  ...}

# %% [markdown]
# How does naive bayes predict classes?
#
# * The objective is to predict the probability of a string( which essentially contains words).
# * To do this, we calculate the probability of each string belonging to different classes, select the maximum and assign labels. This is given in (1).

# %% [markdown]
# $$P(pos|(w1,w2....wn)) = P(pos)*\prod_{i=1}^{n}P(w_{i}|pos)\tag{1} $$
# $$P(neutr|(w1,w2....wn)) = P(neutr)*\prod_{i=1}^{n}P(w_{i}|neutr) $$
# $$P(neg|(w1,w2....wn)) = P(neg)*\prod_{i=1}^{n}P(w_{i}|neg) $$
#
#
#
# $$parameters(pos) =P(W|pos) = \frac{freq_{pos} + \alpha}{N_{pos} + \alpha*V }\tag{2} $$
#
# $$parameters(neutr)= P(W|neutr) = \frac{freq_{neutr} + \alpha}{N_{neutr} + \alpha*V} $$
#
# $$parameters(neg)=P(W|neg) = \frac{freq_{neg} + \alpha}{N_{neg} + \alpha*V} $$
#
#
# where,
# 1. `P(pos|(w1,w2....wn))`: denotes the probability of given string being positive
# 2. `P(pos)`: probability of occurence of positive class
# 3. `P(w_i|pos)`(parameters_pos): denotes the probability of word i being positive, which is calculated by (2)
# 4. `N_pos`: total number of positive words for all comments in the dataset
# 5.  `freq_pos`: frequencies of that specific word in the positive
# 6. `alpha`: Laplacian smoothing parameter **(to avoid division by 0)**
# 7. `V`: length of vocabulary

# %%
# call the helper function to get a list of positive, neutral and negative words

pos_words= word_sentiment(vocab)[0]
neutr_words= word_sentiment(vocab)[1]
neg_words= word_sentiment(vocab)[2]

parameters_pos = {word:0 for word in pos_words}
parameters_neg = {word:0 for word in neg_words}
parameters_neutr = {word:0 for word in neutr_words}

# %%
len(parameters_pos)
# Out:
# 11161

# %%
len(parameters_neutr)
# Out:
# 15602

# %%
len(parameters_neg)
# Out:
# 8588

# %%
def naive_bayes(vocab,X_train,y_train,alpha=1):  
    '''
    Input:
        vocab: vocabulary containing word, label and its frequency
        X_train: dataset containing comments
        y_train: label corresponding to each comment
        alpha: Laplacian smoothing (deafult=1)
    Output:
        parameters_pos,parameters_neg,parameters_neutr: calculations corresponding to each sentiment
                                                        (see formula)
    '''
    
    num_pos=num_neg=num_neutr=0
    # store the total number of each sentiment
    
    for key in vocab.keys():
        # get N_pos, N_neutr, N_neg
        if key[1]==1:
            num_pos+=vocab.get(key,0)
        elif key[1]==0:
            num_neutr+=vocab.get(key,0)
        else:
            num_neg+=vocab.get(key,0)
    
    for word in vocab_words:
        #get frequency of word belonging to the three classes
        pos_freq=find_freq(vocab,word,1)
        neutr_freq=find_freq(vocab,word,0)
        neg_freq=find_freq(vocab,word,-1)
        
        # calculate parameters(see formula)
        prob_pos=(pos_freq+alpha)/(num_pos+vocab_len*alpha)
        prob_neutr=(neutr_freq+alpha)/(num_neutr+vocab_len*alpha)
        prob_neg=(neg_freq+alpha)/(num_neg+vocab_len*alpha)
        
        parameters_pos[word]=prob_pos
        parameters_neg[word]=prob_neg
        parameters_neutr[word]=prob_neutr
        
    return parameters_pos,parameters_neg,parameters_neutr

# %%
parameters_pos,parameters_neg,parameters_neutr=naive_bayes(vocab,X_train,y_train,1)

# %%
len(parameters_neutr)
# Out:
# 35351

# %%
parameters_pos
# Out:
# {'flac': 9.756835272910878e-06,
#  'bahujanahitāya': 4.878417636455439e-06,
#  'bahujanasukhāya': 4.878417636455439e-06,
#  'lokānukampāya': 4.878417636455439e-06,
#  'gautama': 4.878417636455439e-06,
#  'vir': 7.317626454683159e-06,
#  'sanghvi': 1.2196044091138599e-05,
#  '611': 4.878417636455439e-06,
#  'indefens': 7.317626454683159e-06,
#  'inflam': 4.878417636455439e-06,
#  'interfaith': 7.317626454683159e-06,
#  'joy': 5.854101163746527e-05,
#  'unquest': 4.878417636455439e-06,
#  'hitwomen': 7.317626454683159e-06,
#  'madraasa': 4.878417636455439e-06,
#  'flyer': 9.756835272910878e-06,
#  'homepag': 1.7074461727594038e-05,
#  'dharmo': 4.878417636455439e-06,
#  'rakshati': 4.878417636455439e-06,
#  'rakshitaha': 4.878417636455439e-06,
#  'geronimo': 4.878417636455439e-06,
#  'percol': 7.317626454683159e-06,
#  'prefac': 7.317626454683159e-06,
#  'enlightenedcentr': 4.878417636455439e-06,
#  'behest': 7.317626454683159e-06,
#  'milch': 4.878417636455439e-06,
#  'flatter': 7.317626454683159e-06,
#  'edmund': 4.878417636455439e-06,
#  'burk': 4.878417636455439e-06,
#  'dinesh': 7.317626454683159e-06,
#  'submitt': 0.0004561320490085836,
#  'churu': 7.317626454683159e-06,
#  'tempera': 9.756835272910878e-06,
#  'brilliant': 0.00018050145254885124,
#  'unwittingli': 7.317626454683159e-06,
#  'inwardli': 4.878417636455439e-06,
#  'insect': 4.878417636455439e-06,
#  'protégé': 4.878417636455439e-06,
#  'huma': 7.317626454683159e-06,
#  'virupakkha': 4.878417636455439e-06,
#  'erapatha': 4.878417636455439e-06,
#  'chabyaputta': 4.878417636455439e-06,
#  'gotamaka': 4.878417636455439e-06,
#  'doubter': 4.878417636455439e-06,
#  'teleco': 4.878417636455439e-06,
#  'pers': 4.878417636455439e-06,
#  'vid': 1.2196044091138599e-05,
#  'dextermilburn': 9.756835272910878e-06,
#  'diplomaci': 2.9270505818732635e-05,
#  'suscept': 1.4635252909366318e-05,
#  'australiani': 4.878417636455439e-06,
#  'dovremmo': 4.878417636455439e-06,
#  'adattar': 4.878417636455439e-06,
#  'preeti': 4.878417636455439e-06,
#  'cunti': 4.878417636455439e-06,
#  'kao': 4.878417636455439e-06,
#  'balbalatkari': 4.878417636455439e-06,
#  'arithmet': 4.878417636455439e-06,
#  'puller': 9.756835272910878e-06,
#  '282': 4.878417636455439e-06,
#  'scanlat': 9.756835272910878e-06,
#  'vishesh': 4.878417636455439e-06,
#  'samudaay': 4.878417636455439e-06,
#  'poetic': 1.4635252909366318e-05,
#  'awww': 1.9513670545821757e-05,
#  'prayaschit': 4.878417636455439e-06,
#  'dbta': 4.878417636455439e-06,
#  'vdi': 4.878417636455439e-06,
#  'archfrion': 4.878417636455439e-06,
#  '2rs67l2tibdoexufsfp': 4.878417636455439e-06,
#  'remaind': 4.878417636455439e-06,
#  'magnia': 4.878417636455439e-06,
#  'moddi': 4.878417636455439e-06,
#  'summit': 1.4635252909366318e-05,
#  'iou': 4.878417636455439e-06,
#  'grubbi': 4.878417636455439e-06,
#  'kuj': 4.878417636455439e-06,
#  'saalon': 4.878417636455439e-06,
#  'haal': 4.878417636455439e-06,
#  'giregi': 4.878417636455439e-06,
#  'karmon': 4.878417636455439e-06,
#  'fal': 4.878417636455439e-06,
#  'chukana': 4.878417636455439e-06,
#  'gargantuan': 4.878417636455439e-06,
#  'centerist': 4.878417636455439e-06,
#  'annonmy': 4.878417636455439e-06,
#  'tweek': 4.878417636455439e-06,
#  'streamlin': 1.4635252909366318e-05,
#  'wherebjp': 4.878417636455439e-06,
#  'halfwit': 4.878417636455439e-06,
#  'ubderstand': 7.317626454683159e-06,
#  'horro': 4.878417636455439e-06,
#  'coastal': 1.9513670545821757e-05,
#  'sahyadri': 7.317626454683159e-06,
#  'shekru': 4.878417636455439e-06,
#  'malabar': 4.878417636455439e-06,
#  'squirrel': 1.2196044091138599e-05,
#  'arbor': 4.878417636455439e-06,
#  'endem': 4.878417636455439e-06,
#  'endang': 1.2196044091138599e-05,
#  'peculiar': 7.317626454683159e-06,
#  'hindvi': 4.878417636455439e-06,
#  'thich': 9.756835272910878e-06,
#  'nhat': 9.756835272910878e-06,
#  'tnh': 9.756835272910878e-06,
#  'homesid': 4.878417636455439e-06,
#  'samson': 1.4635252909366318e-05,
#  'butler': 4.878417636455439e-06,
#  'kulkarni': 1.4635252909366318e-05,
#  'brathwait': 7.317626454683159e-06,
#  ...}

# %%
# count the total number of each sentiment in the corpus 

pos_corpus=list(y_train).count(1)
neutr_corpus=list(y_train).count(0)
neg_corpus=list(y_train).count(-1)
total=pos_corpus+neg_corpus+neutr_corpus

# %% [markdown]
# The prior probability represents the underlying probability in the target population that a comment is positive, neutral or negative. In other words, if we had no specific information and blindly picked a comment out of the population set, what is the probability that it will belong to one specific class? That is the **"prior"**.
#
# $$P(C_{pos}) = \frac{C_{pos}}{C}{\tag3}$$
#
# Where,
# 1. `C_pos`: number of positive comments(pos_corpus)
# 2. `C`: total number of comments

# %%
# prior ratio calculation

prior_pos=pos_corpus/total
prior_neg=neg_corpus/total
prior_neutr=neutr_corpus/total

# %%
prior_pos
# Out:
# 0.42612470136949426

# %%
prior_neutr
# Out:
# 0.35105488071604024

# %%
prior_neg
# Out:
# 0.2228204179144655

# %%
def predict_NB(comment):
    '''
    Input:
        comment: a string containing text
    Output:
        prob_pos,prob_neg,prob_neutr: probability of the input belonging to the three sentiments
    '''
    list_word=clean_text(comment,stop_words,stemmer)
    #prob_pos=prob_neg=prob_neutr=0
    prob_pos=(prior_pos)
    prob_neg=(prior_neg)
    prob_neutr=(prior_neutr)
    for word in list_word:
        #since essentially all the dic contain the same keys
        if word in  list(parameters_pos.keys()):
            prob_pos*=(parameters_pos[word])
            prob_neg*=(parameters_neg[word])
            prob_neutr*=(parameters_neutr[word])
    return prob_pos,prob_neutr,prob_neg

# %% [markdown]
# ## Part 4: Evaluative results

# %% [markdown]
# ### Testing on random strings

# %%
predict_NB('i am an amazing person') # the probability is highest for positive
# Out:
# (1.9664534576641236e-07, 7.576923559969156e-09, 1.950994940213455e-08)

# %%
predict_NB('feeling sad today') # the probability is highest for negative
# Out:
# (7.521018462641277e-11, 2.9158457955643073e-12, 8.46339140109764e-11)

# %%
predict_NB("it's a beautiful day") # the probability is highest for positive
# Out:
# (1.422067177746586e-07, 3.810110133013061e-09, 1.8095582068077885e-08)

# %%
# a wrong classification
predict_NB("terror attacks on the city") # the probability is highest for positive
# Out:
# (7.543489378369466e-11, 2.984525932073635e-12, 3.036430438832738e-11)

# %%
def test_NB(X_val,y_val):
    '''
    Input:
        X_val: dataset containing comments to be used for testing the model
        y_val: dataset containing labels to be used for testing the model
    Output:
        accuracy: accuracy of the model
    '''
    accuracy=0 #initialise accuracy to zero
    y_pred=[]  #prediction
    
    for comment in X_val:
        # get probabilities corresponding to each class
        pos,neg,neutr=predict_NB(comment)
        
        if(pos>neg) and (pos>neutr): # given comment is positive
            y_pred_i=1
        elif(neg>pos) and (neg>neutr): # given comment is negative
            y_pred_i=-1
        elif(neutr>neg) and (neutr>pos): # given comment is neutral
            y_pred_i=0
        y_pred.append(y_pred_i)
    
    # error is the mean of the differences between y_actual(y_val) and y_pred
    error=np.abs(np.mean(y_val-y_pred))
    accuracy=1-error
    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %(test_NB(X_val, y_val)))
# Out:
# Naive Bayes accuracy = 0.5849

# %% [markdown]
# The accuracy that we get is around 60%, which is good, since it's a basic model and it doesn't take into account the semantic relationship between words.

# %% [markdown]
# ## Part 5: Future scope

# %% [markdown]
# * Different smoothing methods can be tried( we have done Lalplacian, for which alpha=1, Lidstone smoothing, alpha<1)
# * Resampling of model due to skewed distribution of different classes

# %% [markdown]
# Resources used for theory and building the model:
# * https://towardsdatascience.com/introduction-to-na%C3%AFve-bayes-classifier-fa59e3e24aaf
# * https://www.kdnuggets.com/2020/07/spam-filter-python-naive-bayes-scratch.html
# * https://www.datacamp.com/community/tutorials/naive-bayes-scikit-learn
